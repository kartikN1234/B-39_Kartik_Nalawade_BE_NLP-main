# %%
#1 Perform tokenization (Whitespace, Punctuation-based, Treebank, Tweet, MWE) using nltk library. Use porter stemmer and snowball stemmer for stemming. Use any technique for lemmatization. Input / Dataset –use any sample sentence

# %%
# !pip install nltk

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tokenize import TweetTokenizer, TreebankWordTokenizer
from nltk.tokenize import MWETokenizer
from nltk.stem import PorterStemmer, SnowballStemmer
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\anand\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\anand\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\anand\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\anand\AppData\Roaming\nltk_data...
# True

# %%
sentence = "Natural Language Processing is amazing! Let's learn NLP using Python."

# %%
# 1 Whitespace Tokenization
whitespace_tokens = sentence.split()
print("Whitespace Tokenization:", whitespace_tokens)
# Out:
# Whitespace Tokenization: ['Natural', 'Language', 'Processing', 'is', 'amazing!', "Let's", 'learn', 'NLP', 'using', 'Python.']

# %%
# 2 Punctuation-based Tokenization
punct_tokens = word_tokenize(sentence)
print("Punctuation Tokenization:", punct_tokens)
# Out:
# Punctuation Tokenization: ['Natural', 'Language', 'Processing', 'is', 'amazing', '!', 'Let', "'s", 'learn', 'NLP', 'using', 'Python', '.']

# %%
# 3 Treebank Tokenization
treebank = TreebankWordTokenizer()
print("Treebank Tokenization:", treebank.tokenize(sentence))
# Out:
# Treebank Tokenization: ['Natural', 'Language', 'Processing', 'is', 'amazing', '!', 'Let', "'s", 'learn', 'NLP', 'using', 'Python', '.']

# %%
# 4 Tweet Tokenization
tweet_tokenizer = TweetTokenizer()
print("Tweet Tokenization:", tweet_tokenizer.tokenize(sentence))
# Out:
# Tweet Tokenization: ['Natural', 'Language', 'Processing', 'is', 'amazing', '!', "Let's", 'learn', 'NLP', 'using', 'Python', '.']

# %%
# 5 MWE Tokenization
tokenizer = MWETokenizer([('Natural', 'Language')])
print("MWE Tokenization:", tokenizer.tokenize(word_tokenize(sentence)))
# Out:
# MWE Tokenization: ['Natural_Language', 'Processing', 'is', 'amazing', '!', 'Let', "'s", 'learn', 'NLP', 'using', 'Python', '.']

# %%
# Porter Stemmer
porter = PorterStemmer()
print("Porter Stemmer:", [porter.stem(w) for w in punct_tokens])
# Out:
# Porter Stemmer: ['natur', 'languag', 'process', 'is', 'amaz', '!', 'let', "'s", 'learn', 'nlp', 'use', 'python', '.']

# %%
# Snowball Stemmer
snowball = SnowballStemmer("english")
print("Snowball Stemmer:", [snowball.stem(w) for w in punct_tokens])
# Out:
# Snowball Stemmer: ['natur', 'languag', 'process', 'is', 'amaz', '!', 'let', "'s", 'learn', 'nlp', 'use', 'python', '.']

# %%
# Lemmatization
lemmatizer = WordNetLemmatizer()
print("Lemmatization:", [lemmatizer.lemmatize(w) for w in punct_tokens])
# Out:
# Lemmatization: ['Natural', 'Language', 'Processing', 'is', 'amazing', '!', 'Let', "'s", 'learn', 'NLP', 'using', 'Python', '.']
